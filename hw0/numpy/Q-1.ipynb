# %% [markdown]
# <h1> Question 1 <h1>

# %%
import numpy as np

# %% [markdown]
# create array

# %%
random_vector = np.random.randint(10, 1001,1000)
print(random_vector)
# Out:
# [482 245 948 590 948 649 165 949 728  22 781 435  44 644 390 727 943 823
#  273 787 510 118 522 851 775 646 882 255 231 547 652 498 447 467 489 985
#  315 587 787 677 746 598 253 823 570 150 726 698  38  57 443 581 485 245
#  779 564 660 312 860 739 941 572 178 139 185 372 852 853 472 556 425 407
#  379 443 829 855 836 228 420 452  19 854  43 653 338 493 284 856 611 206
#  990 501 526 445 762 346 314 198 708 939 245 522 853 476 387 318 283 577
#  263 156 622 257 422 945 943 184 959 365  34  54 128 289 553 224 127 115
#  336 179 382  40  34 651 861 586 310  34 265  79 764 416 892 865 719 259
#  971 501 455 638 438 968 315 648 882 848  35 507 361  91 643 574 736 821
#   29 217 624 611 614 610  67 824  57 862  55 492 312 971 210 919 463 167
#  835 464 908 867 772 426 289 673 193 196 378 458  64 338  43 242 576 573
#  910 970 862 290 258  77 774 918 242 369 344 714 839 438 959 378 712 226
#  833 642 214 660 408 228  29 158 622 753 994 166 618 705 931 588 842 231
# ...

# %% [markdown]
# find mean

# %%
mean = np.mean(random_vector)
print("mean : " ,mean)
# Out:
# mean 513.908

# %% [markdown]
# find Variance

# %%
variance = np.var(random_vector)
print("var : " ,variance)
# Out:
# var :  79590.781536
